# %%
import pandas as pd
import pymatreader as pmr
import numpy as np

# %%
file_name='S44' #Указать номер человека#
data=pmr.read_mat(f'исходное/{file_name}.mat') #Указать путь к файлу#
df_not_clean=pd.DataFrame(data[file_name])

# %%
useless_demographic=['Age', 'Gender', 'DominantHand', 'Education', 'MaritalStatus', 'Children']
useless_profile=['WeeklySupermarketVisits', 'SupermarketVisitDuration', 'PriceImpact', 'BrandImpact', 'DiscountImpact', 'AdvertisementImpact', 'SuggestionImpact', 'ShoppingList', 'VerbalVisual', 'Spontaneous', 'VarietySeeker', 'UtilitarianMotivation', 'HedonicMotivation', 'Extraversion', 'Neuroticism', 'Agreeableness', 'Openness', 'Conscientiousness', 'BargainHunter']

# %%
df_not_clean.rename(index={
    'education': 'Education',
    'marital_status': 'MaritalStatus'
}, inplace=True)

# %%
useless_products=np.arange(1, 25, 1)
s=[]
for i in useless_products:
    s.append('Product'+str(i))
useless_products=s

# %%
et_useful_data=df_not_clean['ET_clean']
et_useful_data=et_useful_data.drop(useless_demographic+useless_profile+useless_products)
et_useful_data=pd.DataFrame(et_useful_data).transpose()

# %%
et_data=et_useful_data.Data['ET_clean']
et_chans=et_useful_data.chans['ET_clean']

# %%
df_products=df_not_clean.drop(columns=['Profile', 'Demographics', 'EEG_clean', 'ET_clean'])
df_products.drop(useless_demographic+useless_profile+['Data', 'Fs', 'chans'], inplace=True)
useless_pages=['Page1', 'Page2', 'Page3', 'Page4', 'Page5', 'Page6']
num_of_products=24

# %%
df_et=pd.DataFrame()

# %%
#Как-будто не работает#
for t in useless_pages:
    for q in range(24):
        prdct=df_products[t][q]
        et_vrem_seg=prdct['ET_segments']
        for i in et_vrem_seg:
            if isinstance(i, np.int32):
                et_vrem_seg=np.delete(et_vrem_seg, np.where(et_vrem_seg==i)) #?#
# Out:
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\3104736383.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prdct=df_products[t][q]

# %%
prodct=df_products['Page1'][0]
product_info=prodct['ProductInfo']
et_prodct=prodct['ET_segments']

if len(et_prodct)==0:
    pass
else:
    for i in range(len(et_chans)):
        location=et_chans[i]
        et_i=et_data[i]
        et_i_for_prodct=[]
        
        if isinstance(et_prodct[0], np.ndarray):
            for j in et_prodct:
                s=[]
                for k in range(j[1]-j[0]):
                    s.append(et_i[j[0]+k])
                et_i_for_prodct.append(s)
        else:
            s=[]
            for k in range(et_prodct[1]-et_prodct[0]):
                s.append(et_i[et_prodct[0]+k])
            et_i_for_prodct.append(s)
        df_et[f'{location}']=[et_i_for_prodct]

df_et['info']=[product_info]
# Out:
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\910173933.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products['Page1'][0]

# %%
for t in useless_pages:
    for q in range(1, num_of_products):

        dfvrem_et=pd.DataFrame()
        prodct=df_products[t][q]
        product_info=prodct['ProductInfo']
        et_prodct=prodct['ET_segments']

        print(et_prodct)

        if len(et_prodct)==0:
            pass
        else:
            for i in range(len(et_chans)):
                location=et_chans[i]
                et_i=et_data[i]
                et_i_for_prodct=[]
                
                if isinstance(et_prodct[0], np.ndarray):
                    for j in et_prodct:
                        s=[]
                        for k in range(j[1]-j[0]):
                            s.append(et_i[j[0]+k])
                        et_i_for_prodct.append(s)
                else:
                    s=[]
                    for k in range(et_prodct[1]-et_prodct[0]):
                        s.append(et_i[et_prodct[0]+k])
                    et_i_for_prodct.append(s)
                dfvrem_et[f'{location}']=[et_i_for_prodct]
            dfvrem_et['info']=[product_info]
            df_et=pd.concat([df_et, dfvrem_et], ignore_index=True)
df_et.reset_index(inplace=True)
# Out:
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
#  [22858 22960]
#  [23145 23302]
#  [23305 23306]
#  [23314 23315]]
# [[19751 19752]
#  [21332 21372]
#  [23334 23417]]
# [[19810 19911]
#  [22052 22055]
#  [22057 22058]
#  [22184 22225]]
# [[19782 19809]
#  [22055 22184]
#  [22226 22227]
#  [22332 22386]
#  [22401 22402]
#  [22447 22495]]
# [[19752 19782]
#  [22228 22331]
#  [22401 22446]]
# [[24164 24165]
#  [24249 24297]]
# [[23829 23896]
#  [24298 24346]
#  [24664 24665]
#  [24667 24668]
#  [24672 24673]
#  [24681 24685]
#  [24687 24688]
#  [24689 24690]
#  [24705 24706]
#  [24708 24709]
#  [24710 24712]
#  [24715 24717]
#  [24719 24721]
#  [24749 24750]
#  [24751 24752]
#  [24757 24758]
#  [24764 24767]
#  [27476 27477]
#  [27480 27481]
#  [27508 27509]
#  [27543 27544]
#  [27604 27669]]
# []
# [[24163 24164]
#  [24838 24916]
#  [27327 27428]]
# [[23827 23829]
#  [24161 24162]
#  [24663 24664]
#  [24665 24682]
#  [24684 24685]
#  [24686 24837]
#  [27429 27506]]
# [[24918 24948]
#  [26831 26925]
#  [26970 27036]
#  [27105 27106]]
# [[24917 24918]
#  [24920 24921]
#  [24923 24925]
#  [24927 24930]
#  [24935 24936]
#  [24941 24942]
#  [24949 24999]
#  [25001 25003]
#  [25022 25023]
#  [25024 25026]
#  [25035 25036]
#  [25037 25038]
#  [25039 25041]
#  [25043 25046]
#  [25048 25049]
#  [25054 25055]
#  [25057 25058]
#  [26748 26749]
#  [26785 26830]
#  [26926 26969]
#  [27037 27104]
#  [27206 27234]
#  [27237 27238]
#  [27266 27267]
#  [27284 27285]
#  [27286 27287]
#  [27294 27314]]
# [[23767 23807]
#  [24998 25088]
#  [26746 26784]
#  [27234 27316]]
# [[26280 26351]
#  [26374 26379]
#  [26381 26382]
#  [26616 26617]
#  [27106 27204]]
# [[26028 26029]
#  [26055 26056]
#  [26066 26067]
#  [26086 26087]
#  [26088 26092]
#  [26100 26138]
#  [26180 26280]
#  [26352 26449]
#  [26465 26600]
#  [26616 26659]
#  [26661 26662]
#  [26663 26664]
#  [26666 26667]
#  [26673 26674]
#  [26676 26678]
#  [26681 26682]
#  [26685 26720]
#  [26723 26744]
#  [27205 27206]
#  [27317 27318]
#  [28383 28408]
#  [28410 28411]]
# [[24117 24118]
#  [25089 25090]
#  [25723 25724]
#  [25725 25726]
#  [25728 25729]
#  [25730 25731]
#  [25732 25734]
#  [25740 25741]
#  [26026 26099]
#  [26138 26179]
#  [26251 26277]
#  [26654 26744]
#  [28211 28212]
#  [28408 28411]]
# [[23897 23923]
#  [24068 24074]
#  [24076 24079]
#  [24082 24083]
#  [24086 24087]
#  [24094 24095]
#  [24346 24399]
#  [24625 24626]
#  [24632 24633]
#  [24659 24661]
#  [24664 24665]
#  [27508 27602]]
# [[23935 23959]
#  [24033 24068]
#  [24399 24453]
#  [24584 24585]
#  [24587 24588]
#  [24591 24592]
#  [24593 24594]
#  [27673 27708]]
# [[23960 24032]
#  [24454 24493]
#  [24506 24507]
#  [27710 27741]
#  [27754 27793]]
#  [43152 43153]
#  [43445 43446]
#  [43484 43505]
#  [44388 44389]
#  [44390 44391]]
# [[42078 42079]
#  [42227 42268]
#  [43150 43205]
#  [43445 43484]
#  [44056 44057]]
# [[42199 42226]
#  [44058 44092]]
# [[41826 41827]
#  [41839 41840]
#  [41851 41852]
#  [41854 41855]
#  [41858 41859]
#  [41860 41861]
#  [42351 42387]
#  [42413 42414]
#  [43348 43444]]
# [[42309 42350]
#  [43207 43347]
#  [43747 43823]
#  [43939 43964]
#  [44004 44054]]
# [[42269 42308]
#  [43846 43937]]
# [[42495 42497]
#  [43587 43692]
#  [43965 43966]
#  [44146 44190]]
# [[42415 42416]
#  [42454 42495]
#  [43693 43746]
#  [43824 43825]
#  [43834 43835]
#  [44003 44004]
#  [44191 44228]]
# [[42417 42454]
#  [43582 43585]
#  [43836 43844]
#  [43980 44003]
#  [44229 44338]]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]
# C:\Users\Егор\AppData\Local\Temp\ipykernel_6380\1662568629.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prodct=df_products[t][q]

# %%
df_et
# Out:
#      index                                             left_x  \
# 0        0  [[0.19578932, 0.2021533, 0.19725941, 0.2009152...
# 1        1  [[0.23339225, 0.20802774], [0.27457297, 0.2724...
# 2        2  [[0.42508772, 0.42454258, 0.42774543, 0.425089...
# 3        3  [[0.22150046, 0.21575053, 0.21275394, 0.211969...
# 4        4  [[0.28236398], [0.4061389], [0.2628443], [0.21...
# ..     ...                                                ...
# 132    132  [[0.6580611, 0.6628908, 0.6644114, 0.658353, 0...
# 133    133  [[0.76668155, 0.7667493, 0.76917946, 0.7696188...
# 134    134  [[0.45112032, 0.3967449], [0.53184247, 0.51974...
# 135    135  [[0.755996], [0.69195545, 0.6682456, 0.6505877...
# 136    136  [[0.75034976, 0.7513977, 0.76124024, 0.7585457...
#
#                                                 left_y  \
# 0    [[0.15096553, 0.1427856, 0.14859362, 0.1465732...
# 1    [[0.19416139, 0.15326726], [0.14274284, 0.1720...
# 2    [[0.2777737, 0.30092147, 0.31335968, 0.2728693...
# 3    [[0.39166036, 0.40169945, 0.39550516, 0.398818...
# 4    [[0.5335952], [0.44093314], [0.24331814], [0.4...
# ..                                                 ...
# 132  [[0.5776711, 0.5803392, 0.5757092, 0.57313985,...
# 133  [[0.59024143, 0.5777231, 0.5839609, 0.5800396,...
# 134  [[0.7966802, 0.8003112], [0.826953, 0.8164805,...
# 135  [[0.82969385], [0.7970005, 0.802013, 0.7975147...
# 136  [[0.82510656, 0.81963694, 0.8266013, 0.8246639...
#
#                                             left_pupil  \
# 0    [[2.7185059, 2.729477, 2.7384033, 2.737503, 2....
# 1    [[2.7345123, 2.7384186], [2.840454, 2.8864746,...
# 2    [[2.679306, 2.7056427, 2.7221985, 2.6566162, 2...
# 3    [[3.0728912, 3.090744, 3.0687866, 3.0524902, 3...
# 4    [[2.855667], [2.8549194], [2.6780396], [3.0428...
# ..                                                 ...
# 132  [[3.0278168, 3.0477142, 3.0364838, 3.0473328, ...
# 133  [[3.0855255, 3.115036, 3.0985565, 3.0957336, 3...
# 134  [[3.0414276, 3.042572], [2.9439697, 2.9358368,...
# 135  [[3.006607], [3.0475006, 3.0473328, 3.0517883,...
# 136  [[3.0339966, 3.0304565, 3.022705, 3.0235443, 3...
#
#                                                right_x  \
# 0    [[0.22691947, 0.22716221, 0.22899054, 0.223628...
# 1    [[0.26302618, 0.23501608], [0.30668768, 0.2935...
# 2    [[0.4665151, 0.46630982, 0.4669503, 0.46490276...
# 3    [[0.24418534, 0.2321173, 0.23056567, 0.2323126...
# 4    [[0.3023396], [0.44151106], [0.2916372], [0.23...
# ..                                                 ...
# 132  [[0.6819279, 0.68761873, 0.6889479, 0.68309444...
# 133  [[0.78837126, 0.78551424, 0.7833488, 0.7887299...
# 134  [[0.50494415, 0.4204353], [0.5756295, 0.561883...
# 135  [[0.7701481], [0.7114045, 0.6818434, 0.6662679...
# 136  [[0.77847385, 0.775657, 0.7787142, 0.7783664, ...
#
#                                                right_y  \
# 0    [[0.18227847, 0.1697132, 0.17198908, 0.1753164...
# 1    [[0.21909879, 0.18247981], [0.18815808, 0.1924...
# 2    [[0.36550835, 0.3395485, 0.37608227, 0.3609977...
# 3    [[0.43886545, 0.41239268, 0.43012178, 0.432805...
# 4    [[0.5425721], [0.38060686], [0.2868742], [0.44...
# ..                                                 ...
# 132  [[0.60559195, 0.5933982, 0.5904068, 0.61013806...
# 133  [[0.6207281, 0.59979504, 0.60224557, 0.5916795...
# 134  [[0.8047701, 0.8094584], [0.8587655, 0.8609647...
# 135  [[0.84129065], [0.82894826, 0.83171004, 0.8380...
# 136  [[0.84493375, 0.8493928, 0.85599506, 0.8512777...
#
#                                            right_pupil  \
# 0    [[2.8801422, 2.878067, 2.8668976, 2.8776855, 2...
# 1    [[2.8397064, 2.8537445], [3.0197906, 3.0212708...
# 2    [[2.8843231, 2.8025208, 2.8975983, 2.8411102, ...
# 3    [[3.2732697, 3.2041473, 3.212616, 3.2281036, 3...
# 4    [[2.9558563], [2.782959], [2.827896], [3.23555...
# ..                                                 ...
# 132  [[3.2099915, 3.1960297, 3.1688538, 3.1770477, ...
# 133  [[3.2064667, 3.2176056, 3.2254791, 3.179306, 3...
# 134  [[3.221054, 3.258667], [2.9974976, 2.9818115, ...
# 135  [[3.139206], [3.1538696, 3.1604156, 3.1777802,...
# 136  [[3.1306763, 3.141037, 3.1445007, 3.1340332, 3...
#
#                                                   info
# 0    {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# 1    {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# 2    {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# 3    {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# 4    {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# ..                                                 ...
# 132  {'Bought': 1, 'Reasons': 'like', 'Familiarity'...
# 133  {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# 134  {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# 135  {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
# 136  {'Bought': 0, 'Reasons': [], 'Familiarity': 0,...
#
# [137 rows x 8 columns]

# %%
df_et.to_csv(f'et_{file_name}.csv')
